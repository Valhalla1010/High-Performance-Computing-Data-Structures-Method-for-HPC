# %%
! python -m pytest -v Julia_test.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.10, pytest-8.3.4, pluggy-1.5.0 -- C:\Program Files\Python39\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\davii\OneDrive\Skrivbord\Assignment ll\Exercise 1
# plugins: anyio-4.8.0
# collecting ... collected 1 item
#
# Julia_test.py::test_julia PASSED                                         [100%]
#
# ============================== 1 passed in 7.30s ==============================

# %%
! python -m pytest -v -s Julia_unittest.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.10, pytest-8.3.4, pluggy-1.5.0 -- C:\Program Files\Python39\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\davii\OneDrive\Skrivbord\Assignment ll\Exercise 1
# plugins: anyio-4.8.0
# collecting ... collected 1 item
#
# Julia_unittest.py::test_julia
# Fetching data from db
# Length of x: 50
# Total elements: 2500
# calculate_z_serial_purepython took 0.007009744644165039 seconds
# Length of x: 401
# Total elements: 160801
# calculate_z_serial_purepython took 0.44771790504455566 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 2.7816717624664307 seconds
# Length of x: 100
# Total elements: 10000
# calculate_z_serial_purepython took 0.06406569480895996 seconds
# Length of x: 401
# Total elements: 160801
# calculate_z_serial_purepython took 0.7378396987915039 seconds
# Length of x: 1000
# Total elements: 1000000
# ...
